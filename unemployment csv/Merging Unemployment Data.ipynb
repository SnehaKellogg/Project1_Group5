# %%
# Dependencies
import pandas as pd
import numpy as np

# %%
# Creating Dataframe for 2009
csv_path = "State_UI_2009.csv"
unemployment09_df = pd.read_csv(csv_path)
unemployment09_df.head()
# Out:
#         State  Year  Jan.  Feb.  Mar.  April   May  June  July  Aug.  Sept.  \
# 0     Alabama  2009   7.8   8.4   9.0    9.0   9.8  10.1  10.2  10.4   10.7
# 1      Alaska  2009   7.9   8.0   8.5    8.0   8.4   8.4   8.3   8.3    8.4
# 2     Arizona  2009   7.0   7.4   7.8    7.7   8.2   8.7   9.2   9.1    9.1
# 3    Arkansas  2009   6.4   6.6   6.5    6.5   7.0   7.2   7.4   7.1    7.1
# 4  California  2009  10.1  10.5  11.2   11.0  11.5  11.6  11.9  12.2   12.2
#
#    Oct.  Nov.  Dec.  Avg UI
# 0  10.9  10.5  11.0     9.8
# 1   8.9   8.7   8.8     8.4
# 2   9.3   8.9   9.1     8.5
# 3   7.6   7.4   7.7     7.0
# 4  12.5  12.3  12.4    11.6

# %%
df1 = pd.DataFrame(unemployment09_df)
info_pd09 = pd.DataFrame(unemployment09_df, columns=["State", "Year", "Avg UI"])
info_pd09
# Out:
#              State  Year  Avg UI
# 0          Alabama  2009     9.8
# 1           Alaska  2009     8.4
# 2          Arizona  2009     8.5
# 3         Arkansas  2009     7.0
# 4       California  2009    11.6
# 5         Colorado  2009     7.3
# 6      Connecticut  2009     8.0
# 7         Delaware  2009     8.1
# 8             D.C.  2009    10.8
# 9          Florida  2009    10.4
# 10         Georgia  2009     9.8
# 11          Hawaii  2009     7.0
# 12           Idaho  2009     8.1
# 13        Illinois  2009     9.9
# 14         Indiana  2009     9.9
# 15            Iowa  2009     6.0
# 16          Kansas  2009     6.6
# 17        Kentucky  2009    10.4
# 18       Louisiana  2009     6.7
# 19           Maine  2009     8.2
# 20        Maryland  2009     7.1
# 21   Massachusetts  2009     8.5
# 22        Michigan  2009    14.0
# 23       Minnesota  2009     7.9
# 24     Mississippi  2009     9.4
# 25        Missouri  2009     9.0
# 26         Montana  2009     6.3
# ...

# %%
# Creating Dataframe for 2010
csv_path = "State_UI_2010.csv"
unemployment10_df = pd.read_csv(csv_path)
unemployment10_df.head()
# Out:
#         State  Year  Jan.  Feb.  March  April   May  June  July  Aug.  Sept.  \
# 0     Alabama  2010  11.1  11.1   11.0   11.0  10.7  10.3   9.7   9.2    8.9
# 1      Alaska  2010   8.5   8.5    8.5    8.4   8.2   7.9   7.7   7.7    7.8
# 2     Arizona  2010   9.2   9.5    9.6    9.5   9.6   9.6   9.6   9.7    9.7
# 3    Arkansas  2010   7.6   7.7    7.8    7.8   7.7   7.5   7.4   7.5    7.7
# 4  California  2010  12.5  12.5   12.6   12.5  12.4  12.3  12.3  12.4   12.4
#
#    Oct.  Nov.  Dec.  Avg UI
# 0   8.9   9.0   9.1    10.0
# 1   7.9   8.0   8.1     8.1
# 2   9.5   9.4   9.4     9.5
# 3   7.8   7.9   7.9     7.7
# 4  12.4  12.4  12.5    12.4

# %%
df2 = pd.DataFrame(unemployment10_df)
info_pd10 = pd.DataFrame(unemployment10_df, columns=["State", "Year", "Avg UI"])
info_pd10
# Out:
#              State  Year  Avg UI
# 0          Alabama  2010    10.0
# 1           Alaska  2010     8.1
# 2          Arizona  2010     9.5
# 3         Arkansas  2010     7.7
# 4       California  2010    12.4
# 5         Colorado  2010     8.1
# 6      Connecticut  2010     9.0
# 7         Delaware  2010     8.7
# 8               DC  2010    10.5
# 9          Florida  2010    11.9
# 10         Georgia  2010    10.2
# 11          Hawaii  2010     6.6
# 12           Idaho  2010     9.2
# 13        Illinois  2010    10.5
# 14         Indiana  2010     9.9
# 15            Iowa  2010     6.7
# 16          Kansas  2010     6.6
# 17        Kentucky  2010    10.3
# 18       Louisiana  2010     7.4
# 19           Maine  2010     7.9
# 20        Maryland  2010     7.4
# 21   Massachusetts  2010     8.9
# 22        Michigan  2010    13.3
# 23       Minnesota  2010     7.1
# 24     Mississippi  2010    10.7
# 25        Missouri  2010     9.4
# 26         Montana  2010     7.2
# ...

# %%
# Creating Dataframe for 2011
csv_path = "State_UI_2011.csv"
unemployment11_df = pd.read_csv(csv_path)
unemployment11_df.head()
# Out:
#         State  Year   Jan   Feb   Mar   Apr   May  June  July   Aug  Sept  \
# 0     Alabama  2011   9.3   9.3   9.2   9.3   9.6   9.9  10.0   9.9   9.8
# 1      Alaska  2011   7.7   7.6   7.4   7.3   7.4   7.5   7.7   7.7   7.6
# 2     Arizona  2011   9.6   9.6   9.5   9.3   9.1   9.3   9.4   9.3   9.1
# 3    Arkansas  2011   7.8   7.8   7.8   7.7   7.8   8.1   8.2   8.3   8.3
# 4  California  2011  12.4  12.2  12.0  11.9  11.7  11.8  12.0  12.1  11.9
#
#     Oct   Nov   Dec  Avg UI
# 0   9.3   8.7   8.1     9.4
# 1   7.4   7.3   7.3     7.5
# 2   9.0   8.7   8.7     9.2
# 3   8.2   8.0   7.7     8.0
# 4  11.7  11.3  11.1    11.8

# %%
df3 = pd.DataFrame(unemployment11_df)
info_pd11 = pd.DataFrame(unemployment11_df, columns=["State", "Year", "Avg UI"])
info_pd11
# Out:
#              State  Year  Avg UI
# 0          Alabama  2011     9.4
# 1           Alaska  2011     7.5
# 2          Arizona  2011     9.2
# 3         Arkansas  2011     8.0
# 4       California  2011    11.8
# 5         Colorado  2011     8.6
# 6      Connecticut  2011     8.9
# 7         Delaware  2011     8.1
# 8             D.C.  2011    10.3
# 9          Florida  2011    10.7
# 10         Georgia  2011    10.1
# 11          Hawaii  2011     6.3
# 12           Idaho  2011     9.2
# 13        Illinois  2011     9.4
# 14         Indiana  2011     8.7
# 15            Iowa  2011     6.0
# 16          Kansas  2011     6.6
# 17        Kentucky  2011     9.8
# 18       Louisiana  2011     7.5
# 19           Maine  2011     7.5
# 20        Maryland  2011     7.0
# 21   Massachusetts  2011     7.6
# 22        Michigan  2011    10.4
# 23       Minnesota  2011     6.6
# 24     Mississippi  2011    10.4
# 25        Missouri  2011     8.8
# 26         Montana  2011     7.4
# ...

# %%
# Creating Dataframe for 2012
csv_path = "State_UI_2012.csv"
unemployment12_df = pd.read_csv(csv_path)
unemployment12_df.head()
# Out:
#         State  Year   Jan   Feb   Mar   Apr   May  June  July   Aug  Sept  \
# 0     Alabama  2012   7.8   7.6   7.3   7.2   7.4   7.8   8.3   8.5   8.3
# 1      Alaska  2012   7.2   7.1   7.0   6.9   7.0   7.3   7.7   7.8   7.5
# 2     Arizona  2012   8.7   8.7   8.6   8.2   8.2   8.2   8.3   8.3   8.2
# 3    Arkansas  2012   7.6   7.6   7.4   7.2   7.3   7.2   7.3   7.3   7.1
# 4  California  2012  10.9  10.9  11.0  10.9  10.8  10.7  10.7  10.6  10.2
#
#     Oct  Nov  Dec  Avg UI
# 0   8.1  7.5  7.1     7.7
# 1   7.1  6.8  6.6     7.2
# 2   8.1  7.8  7.9     8.3
# 3   7.2  7.0  7.1     7.3
# 4  10.1  9.8  9.8    10.5

# %%
df4 = pd.DataFrame(unemployment12_df)
info_pd12 = pd.DataFrame(unemployment12_df, columns=["State", "Year", "Avg UI"])
info_pd12
# Out:
#              State  Year  Avg UI
# 0          Alabama  2012     7.7
# 1           Alaska  2012     7.2
# 2          Arizona  2012     8.3
# 3         Arkansas  2012     7.3
# 4       California  2012    10.5
# 5         Colorado  2012     7.9
# 6      Connecticut  2012     8.3
# 7         Delaware  2012     6.8
# 8             D.C.  2012     9.1
# 9          Florida  2012     8.7
# 10         Georgia  2012     9.0
# 11          Hawaii  2012     6.0
# 12           Idaho  2012     7.5
# 13        Illinois  2012     8.9
# 14         Indiana  2012     8.2
# 15            Iowa  2012     5.2
# 16          Kansas  2012     6.0
# 17        Kentucky  2012     8.4
# 18       Louisiana  2012     6.9
# 19           Maine  2012     7.3
# 20        Maryland  2012     6.7
# 21   Massachusetts  2012     6.5
# 22        Michigan  2012     8.9
# 23       Minnesota  2012     5.7
# 24     Mississippi  2012     9.0
# 25        Missouri  2012     7.1
# 26         Montana  2012     6.2
# ...

# %%
# Creating Dataframe for 2013
csv_path = "State_UI_2013.csv"
unemployment13_df = pd.read_csv(csv_path)
unemployment13_df.head()
# Out:
#         State  Year  Jan  Feb  Mar  Apr  May  June  July  Aug  Sept  Oct  Nov  \
# 0     Alabama  2013  6.9  7.2  7.2  6.9  6.8   6.5   6.3  6.3   6.4  6.5  6.2
# 1      Alaska  2013  6.7  6.5  6.2  6.0  5.9   6.1   6.3  6.5   6.5  6.5  6.4
# 2     Arizona  2013  8.0  7.9  7.9  7.9  7.8   8.0   8.0  8.3   8.3  8.2  7.8
# 3    Arkansas  2013  7.2  7.2  7.2  7.1  7.3   7.3   7.4  7.4   7.4  7.5  7.5
# 4  California  2013  9.8  9.6  9.4  9.0  8.6   8.5   8.7  8.9   8.7  8.7  8.5
#
#    Dec  Avg UI
# 0  6.1     6.6
# 1  6.4     6.3
# 2  7.6     8.0
# 3  7.4     7.3
# 4  8.3     8.9

# %%
df5 = pd.DataFrame(unemployment13_df)
info_pd13 = pd.DataFrame(unemployment13_df, columns=["State", "Year", "Avg UI"])
info_pd13
# Out:
#              State  Year  Avg UI
# 0          Alabama  2013     6.6
# 1           Alaska  2013     6.3
# 2          Arizona  2013     8.0
# 3         Arkansas  2013     7.3
# 4       California  2013     8.9
# 5         Colorado  2013     6.9
# 6      Connecticut  2013     7.9
# 7         Delaware  2013     7.1
# 8             D.C.  2013     8.6
# 9          Florida  2013     7.1
# 10         Georgia  2013     8.3
# 11          Hawaii  2013     4.7
# 12           Idaho  2013     6.3
# 13        Illinois  2013     9.1
# 14         Indiana  2013     8.1
# 15            Iowa  2013     4.7
# 16          Kansas  2013     5.6
# 17        Kentucky  2013     8.2
# 18       Louisiana  2013     6.5
# 19           Maine  2013     6.9
# 20        Maryland  2013     6.7
# 21   Massachusetts  2013     6.9
# 22        Michigan  2013     8.7
# 23       Minnesota  2013     5.1
# 24     Mississippi  2013     8.8
# 25        Missouri  2013     6.7
# 26         Montana  2013     5.4
# ...

# %%
# Creating Dataframe for 2014
csv_path = "State_UI_2014.csv"
unemployment14_df = pd.read_csv(csv_path)
unemployment14_df.head()
# Out:
#         State  Year  Jan  Feb  Mar  Apr  May  June  July  Aug  Sept  Oct  Nov  \
# 0     Alabama  2014  6.1  6.4  6.7  6.9  6.8   6.8   7.0  6.9   6.6  6.3  6.0
# 1      Alaska  2014  6.4  6.5  6.6  6.4  6.4   6.4   6.5  6.8   6.8  6.8  6.6
# 2     Arizona  2014  7.5  7.3  7.3  6.9  6.8   6.9   7.0  7.1   6.9  6.8  6.8
# 3    Arkansas  2014  7.3  7.1  6.9  6.6  6.4   6.2   6.2  6.3   6.2  6.0  5.8
# 4  California  2014  8.1  8.0  8.1  7.8  7.6   7.4   7.4  7.4   7.3  7.3  7.2
#
#    Dec  Avg UI
# 0  5.7     6.5
# 1  6.3     6.5
# 2  6.7     7.0
# 3  5.7     6.4
# 4  7.0     7.6

# %%
df6 = pd.DataFrame(unemployment14_df)
info_pd14 = pd.DataFrame(unemployment14_df, columns=["State", "Year", "Avg UI"])
info_pd14
# Out:
#              State  Year  Avg UI
# 0          Alabama  2014     6.5
# 1           Alaska  2014     6.5
# 2          Arizona  2014     7.0
# 3         Arkansas  2014     6.4
# 4       California  2014     7.6
# 5         Colorado  2014     5.3
# 6      Connecticut  2014     6.7
# 7         Delaware  2014     6.1
# 8             D.C.  2014     7.5
# 9          Florida  2014     6.1
# 10         Georgia  2014     7.4
# 11          Hawaii  2014     4.3
# 12           Idaho  2014     4.7
# 13        Illinois  2014     7.3
# 14         Indiana  2014     5.9
# 15            Iowa  2014     4.4
# 16          Kansas  2014     4.7
# 17        Kentucky  2014     7.1
# 18       Louisiana  2014     5.4
# 19           Maine  2014     5.8
# 20        Maryland  2014     5.8
# 21   Massachusetts  2014     6.0
# 22        Michigan  2014     7.3
# 23       Minnesota  2014     4.4
# 24     Mississippi  2014     7.6
# 25        Missouri  2014     6.2
# 26         Montana  2014     4.7
# ...

# %%
# Creating Dataframe for 2015
csv_path = "State_UI_2015.csv"
unemployment15_df = pd.read_csv(csv_path)
unemployment15_df.head()
# Out:
#         State  Year  Jan.  Feb.  Mar.  Apr.  May  June  July  Aug.  Sept.  \
# 0     Alabama  2015   6.0   5.8   5.7   5.8  6.1   6.1   6.2   6.2    6.0
# 1      Alaska  2015   6.3   6.3   6.5   6.7  6.8   6.8   6.7   6.6    6.4
# 2     Arizona  2015   6.6   6.5   6.2   6.0  5.8   5.9   6.1   6.3    6.3
# 3    Arkansas  2015   5.6   5.5   5.6   5.7  5.7   5.7   5.6   5.4    5.2
# 4  California  2015   6.9   6.7   6.5   6.3  6.4   6.3   6.2   6.1    5.9
#
#    Oct.  Nov.  Dec.  Avg UI
# 0   5.9   6.0   6.2     6.0
# 1   6.4   6.4   6.5     6.5
# 2   6.1   6.0   5.8     6.1
# 3   5.1   5.0   4.8     5.4
# 4   5.8   5.7   5.8     6.2

# %%
df7 = pd.DataFrame(unemployment15_df)
info_pd15 = pd.DataFrame(unemployment15_df, columns=["State", "Year", "Avg UI"])
info_pd15
# Out:
#              State  Year  Avg UI
# 0          Alabama  2015     6.0
# 1           Alaska  2015     6.5
# 2          Arizona  2015     6.1
# 3         Arkansas  2015     5.4
# 4       California  2015     6.2
# 5         Colorado  2015     4.1
# 6      Connecticut  2015     5.7
# 7         Delaware  2015     4.8
# 8             D.C.  2015     7.1
# 9          Florida  2015     5.4
# 10         Georgia  2015     6.0
# 11          Hawaii  2015     3.7
# 12           Idaho  2015     4.0
# 13        Illinois  2015     5.8
# 14         Indiana  2015     5.0
# 15            Iowa  2015     3.8
# 16          Kansas  2015     4.3
# 17        Kentucky  2015     5.1
# 18       Louisiana  2015     6.4
# 19           Maine  2015     4.6
# 20        Maryland  2015     5.3
# 21   Massachusetts  2015     4.7
# 22        Michigan  2015     5.4
# 23       Minnesota  2015     3.8
# 24     Mississippi  2015     6.5
# 25        Missouri  2015     5.4
# 26         Montana  2015     4.1
# ...

# %%
# Creating Dataframe for 2016
csv_path = "State_UI_2016.csv"
unemployment16_df = pd.read_csv(csv_path)
unemployment16_df.head()
# Out:
#         State  Year  Jan.  Feb.  Mar.  Apr.  May  June  July  Aug.  Sept.  \
# 0     Alabama  2016   6.0   6.0   5.9   5.9  5.8   5.8   5.8   5.8    5.9
# 1      Alaska  2016   6.7   6.8   6.8   6.8  6.9   6.9   7.0   7.0    7.0
# 2     Arizona  2016   5.7   5.6   5.5   5.5  5.4   5.4   5.3   5.3    5.2
# 3    Arkansas  2016   4.2   4.1   4.1   4.0  4.0   4.0   3.9   3.9    3.9
# 4  California  2016   5.7   5.6   5.6   5.5  5.5   5.5   5.5   5.4    5.4
#
#    Oct.  Nov.  Dec.  Avg UI
# 0   5.9   5.8   5.7     5.9
# 1   7.0   7.0   7.0     6.9
# 2   5.2   5.2   5.2     5.4
# 3   3.8   3.8   3.7     4.0
# 4   5.4   5.4   5.3     5.5

# %%
df8 = pd.DataFrame(unemployment16_df)
info_pd16 = pd.DataFrame(unemployment16_df, columns=["State", "Year", "Avg UI"])
info_pd16
# Out:
#              State  Year  Avg UI
# 0          Alabama  2016     5.9
# 1           Alaska  2016     6.9
# 2          Arizona  2016     5.4
# 3         Arkansas  2016     4.0
# 4       California  2016     5.5
# 5         Colorado  2016     3.3
# 6      Connecticut  2016     5.2
# 7         Delaware  2016     4.5
# 8             D.C.  2016     6.1
# 9          Florida  2016     4.8
# 10         Georgia  2016     5.4
# 11          Hawaii  2016     3.0
# 12           Idaho  2016     3.8
# 13        Illinois  2016     5.8
# 14         Indiana  2016     4.4
# 15            Iowa  2016     3.6
# 16          Kansas  2016     4.0
# 17        Kentucky  2016     5.2
# 18       Louisiana  2016     6.1
# 19           Maine  2016     3.8
# 20        Maryland  2016     4.4
# 21   Massachusetts  2016     3.9
# 22        Michigan  2016     5.0
# 23       Minnesota  2016     3.9
# 24     Mississippi  2016     5.8
# 25        Missouri  2016     4.6
# 26         Montana  2016     4.1
# ...

# %%
# Creating Dataframe for 2017
csv_path = "State_UI_2017.csv"
unemployment17_df = pd.read_csv(csv_path)
unemployment17_df.head()
# Out:
#         State  Year  Jan.  Feb.  Mar.  Apr.  May  June  July  Aug.  Sept.  \
# 0     Alabama  2017   5.5   5.3   5.0   4.8  4.6   4.3   4.1   4.0    3.9
# 1      Alaska  2017   7.0   7.0   7.1   7.1  7.1   7.2   7.2   7.2    7.2
# 2     Arizona  2017   5.2   5.1   5.1   5.0  4.9   4.8   4.7   4.7    4.7
# 3    Arkansas  2017   3.7   3.6   3.6   3.6  3.6   3.7   3.7   3.7    3.7
# 4  California  2017   5.2   5.1   5.0   5.0  4.9   4.8   4.7   4.6    4.5
#
#    Oct.  Nov.  Dec.  Avg UI
# 0   3.8   3.8   3.8     4.4
# 1   7.2   7.2   7.2     7.1
# 2   4.7   4.7   4.7     4.9
# 3   3.7   3.7   3.7     3.7
# 4   4.5   4.5   4.5     4.8

# %%
df9 = pd.DataFrame(unemployment17_df)
info_pd17 = pd.DataFrame(unemployment17_df, columns=["State", "Year", "Avg UI"])
info_pd17
# Out:
#              State  Year  Avg UI
# 0          Alabama  2017     4.4
# 1           Alaska  2017     7.1
# 2          Arizona  2017     4.9
# 3         Arkansas  2017     3.7
# 4       California  2017     4.8
# 5         Colorado  2017     2.8
# 6      Connecticut  2017     4.7
# 7         Delaware  2017     4.6
# 8             D.C.  2017     6.1
# 9          Florida  2017     4.2
# 10         Georgia  2017     4.8
# 11          Hawaii  2017     2.4
# 12           Idaho  2017     3.2
# 13        Illinois  2017     5.0
# 14         Indiana  2017     3.6
# 15            Iowa  2017     3.1
# 16          Kansas  2017     3.6
# 17        Kentucky  2017     4.9
# 18       Louisiana  2017     5.2
# 19           Maine  2017     3.3
# 20        Maryland  2017     4.1
# 21   Massachusetts  2017     3.7
# 22        Michigan  2017     4.6
# 23       Minnesota  2017     3.5
# 24     Mississippi  2017     5.1
# 25        Missouri  2017     3.7
# 26         Montana  2017     4.0
# ...

# %%
# Merge two dataframes using an inner join
merge_table1 = pd.merge(info_pd09, info_pd10, on="State")

# %%
# adding 2011 data to merge
merge_table2 = pd.merge(merge_table1, info_pd11, on="State")

# %%
# adding 2012 data to merge
merge_table3 = pd.merge(merge_table2, info_pd12, on="State")

# %%
# adding 2013 data to merge
merge_table4 = pd.merge(merge_table3, info_pd13, on="State")

# %%
# adding 2014 data to merge
merge_table5 = pd.merge(merge_table4, info_pd14, on="State")

# %%
# adding 2015 data to merge
merge_table6 = pd.merge(merge_table5, info_pd15, on="State")

# %%
# adding 2016 data to merge
merge_table7 = pd.merge(merge_table6, info_pd16, on="State")

# %%
# adding 2017 data to merge
merge_table8 = pd.merge(merge_table7, info_pd17, on="State")
merge_table8
# Out:
#              State  Year_x  Avg UI_x  Year_y  Avg UI_y  Year_x  Avg UI_x  \
# 0          Alabama    2009       9.8    2010      10.0    2011       9.4
# 1           Alaska    2009       8.4    2010       8.1    2011       7.5
# 2          Arizona    2009       8.5    2010       9.5    2011       9.2
# 3         Arkansas    2009       7.0    2010       7.7    2011       8.0
# 4       California    2009      11.6    2010      12.4    2011      11.8
# 5         Colorado    2009       7.3    2010       8.1    2011       8.6
# 6      Connecticut    2009       8.0    2010       9.0    2011       8.9
# 7         Delaware    2009       8.1    2010       8.7    2011       8.1
# 8          Florida    2009      10.4    2010      11.9    2011      10.7
# 9          Georgia    2009       9.8    2010      10.2    2011      10.1
# 10          Hawaii    2009       7.0    2010       6.6    2011       6.3
# 11           Idaho    2009       8.1    2010       9.2    2011       9.2
# ...
