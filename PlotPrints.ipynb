# %% [markdown]
# # Plot Prints

# %%
from IPython.display import Image, display

# %% [markdown]
# ## Primary data study

# %% [markdown]
# ### Yearly trends and Data structure

# %% [markdown]
# #### Unemployment trends downward as we come closer to the present.  consistent with post recession dynamics.

# %%
#Unemployment has decreased over years and 2019 is at the lowest for US in history

Image('plots/Average Unemployment Index.png')

# %% [markdown]
# #### Crime rates remained consistent with a very slight decline YOY and the largest decline from 2013 to 2014.

# %%
# Crime has decreased over the years
Image('plots/Average Crime Rate.png')

# %%
#Puerto Rico and Nevada are amongst the highest on unemployment
Image('plots/Average Unemployment Index by State.png', embed = True)

# %%
#Unfortunately Puerto Rico is not available in the Crime Data
## Nevada has high crime rate but not the highest
Image('plots/Average Crime Rate by State.png')

# %%
from IPython.display import HTML, display
display(HTML("<table><tr><td><img src='plots/Average Minimum Wage.png'></td><td><img src='plots/Average Adjusted Minimum Wage.png'></td></tr></table>"))
# Out:
# <table><tr><td><img src='plots/Average Minimum Wage.png'></td><td><img src='plots/Average Adjusted Minimum Wage.png'></td></tr></table>

# %%
#Relation of CPI Index with the Average Minimum Wage
display(HTML("<table><tr><td><img src='plots/Actual Min wage with CPI.png'></td><td><img src='plots/Adjusted minimum wage vs CPI.png'></td></tr></table>"))
# Out:
# <table><tr><td><img src='plots/Actual Min wage with CPI.png'></td><td><img src='plots/Adjusted minimum wage vs CPI.png'></td></tr></table>

# %%
#Groups of year indicating they move together - Bubble colors represent years
Image("plots/Unemployment and Crime index.png")

# %% [markdown]
# ## Showing relation of the variables in paired plotting of relevant variables

# %%
Image("plots/pairedrelation.png")

# %% [markdown]
# ### Observations:
# 1. Adjusted Minimum wage has two clear bins - needs to be explored later
# 2. Average Unimployment has marginally decreased with rise in Adjusted Minimum Wage. This is more pronounced for States where Crime rate has been significantly low.
# 3. Adj Min Wage has a negative relation with Crime Rate. This becomes all the more clear in binned data where the trend plot is almost flat for low crime rate states
# 4. Overall Crime Rate has significantly decreased over the years with the rate being the highest for high crime rate states as expected.
# 5. Average Unemployment is at its lowest for all the years now.

# %%
Image("plots/pairedrelationbinned.png")

# %% [markdown]
# ## Deep Diving

# %% [markdown]
# ### Relation between Average Unemployment and Crime Rate for the States
# Note: the data used has already been treated for robustness i.e. the outliers are being ignored

# %%
#Relation of CPI Index with the Average Minimum Wage
display(HTML("<table><tr><td><img src='plots/Avg UI_binned_fit.png'></td><td><img src='plots/Yearflow_UI_wage_binned.png'></td></tr></table>"))
# Out:
# <table><tr><td><img src='plots/Avg UI_binned_fit.png'></td><td><img src='plots/Yearflow_UI_wage_binned.png'></td></tr></table>

# %% [markdown]
# ### Observation:
# Average unemployment has decreased rapidly (highest negative slope) for Medium Crime states , overall converging for all states.

# %%
Image("plots/Unemployment and Crime index1.png")

# %%
Image("plots/UI_States.png")

# %%
Image("plots/UI_wage_States_High.png")

# %%
Image("plots/UI_wage_States_Medium.png")

# %%
Image("plots/UI_wage_States_Low.png")

# %% [markdown]
# ##### The plots suggest that there is a good coorelation between Total Crime Rate and Avg UI
# We can not conduct t-test because of the outlier issue for Min wage, negating the test results.

# %%
Image('plots/Correlation.JPG')

# %% [markdown]
# #### Adding significance level using pearson coefficient

# %%
Image('plots/Pearson_significance.PNG')
