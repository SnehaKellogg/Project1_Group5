# %%
import pandas as pd
import numpy as np
import matplotlib as plt

#Load in the data
minimum_wage_data = "Resources/Minimum Wage Data.csv"

minimum_wage_df = pd.read_csv(minimum_wage_data, encoding="ISO-8859-1")
minimum_wage_df.head()
# Out:
#    Year       State           Table_Data Footnote  High.Value  Low.Value  \
# 0  1968     Alabama                  ...      NaN     0.00000    0.00000
# 1  1968      Alaska                 2.10      NaN     2.10000    2.10000
# 2  1968     Arizona  18.72 - 26.40/wk(b)      (b)     0.66000    0.46800
# 3  1968    Arkansas          1.25/day(b)      (b)     0.15625    0.15625
# 4  1968  California              1.65(b)      (b)     1.65000    1.65000
#
#    CPI.Average  High.2018  Low.2018
# 0    34.783333       0.00      0.00
# 1    34.783333      15.12     15.12
# 2    34.783333       4.75      3.37
# 3    34.783333       1.12      1.12
# 4    34.783333      11.88     11.88

# %%
minimum_wage_df.groupby('State').plot(minimum_wage_df["Year"],minimum_wage_df["High.Value"] )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     917             try:
# --> 918                 result = self._python_apply_general(f)
#     919             except Exception:
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     935         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 936                                                    self.axis)
#     937
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, f, data, axis)
#    2272             group_axes = _get_axes(group)
# -> 2273             res = f(group)
# ...
