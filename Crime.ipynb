# %%
import pandas as pd

# %%
#read crime data cleaned 
crime = pd.read_csv("crime_cleaned.csv")

# %%
#reading the df
crime.head()
# Out:
#      State  Year  Violent Crime rate  \
# 0  Alabama  2000               486.2
# 1  Alabama  2001               438.2
# 2  Alabama  2002               445.0
# 3  Alabama  2003               429.2
# 4  Alabama  2004               427.0
#
#    Murder and nonnegligent manslaughter rate  Rape rate  Robbery rate  \
# 0                                        7.4       33.3         128.2
# 1                                        8.5       30.6         125.0
# 2                                        6.8       37.2         133.1
# 3                                        6.6       36.8         134.1
# 4                                        5.6       38.5         133.5
#
#    Aggravated assault rate  Property crime rate  Burglary rate  \
# 0                    317.2               4059.7          906.9
# 1                    274.1               3876.8          909.4
# 2                    268.0               4027.8          950.6
# ...

# %%
#extracting the total crime rate to merge with rest of dataset
crimetotal = crime.filter(["State", "Year","Total Crime Rate"],axis = 1)
crimetotal.head()
# Out:
#      State  Year  Total Crime Rate
# 0  Alabama  2000            9091.7
# 1  Alabama  2001            8630.0
# 2  Alabama  2002            8945.6
# 3  Alabama  2003            8951.2
# 4  Alabama  2004            8912.6

# %%
crimetotal.to_csv("crimetotal.csv")
